# %% [markdown]
# # EDA

# %% [markdown]
# ## IMPORTAR PAQUETES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

#Automcompletar rápido
# %config IPCompleter.greedy=True

# %% [markdown]
# ## IMPORTAR LOS DATOS

# %% [markdown]
# Sustituir la ruta del proyecto.

# %%
ruta_proyecto = '/Users/julian/Desktop/DS4B Mastery Course/EstructuraDirectorio/03_MACHINE_LEARNING/07_CASOS/CASO_ML3_SCORING_DE_RIESGOS/03_RIESGOS'

# %% [markdown]
# Nombres de los ficheros de datos.

# %%
nombre_cat = 'cat_resultado_calidad.pickle'
nombre_num = 'num_resultado_calidad.pickle'

# %% [markdown]
# Cargar los datos.

# %%
cat = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_cat)
num = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_num)

# %% [markdown]
# ## EDA CATEGÓRICAS

# %% [markdown]
# ### Análisis estadístico

# %%
variables = ['antigüedad_empleo', 'ingresos_verificados', 'rating', 'vivienda',
       'finalidad', 'num_cuotas', 'estado']

# %%
def frecuencias_cat(df_cat):
    resultado = df_cat[variables].apply(lambda x: x.value_counts(normalize = True)).T.stack()\
                .to_frame().reset_index()\
                .rename(columns={'level_0':'Variable','level_1':'Valor',0: "Frecuencia"})\
                .sort_values(by = ['Variable','Frecuencia'])
    return(resultado)

# %%
frecuencias_cat(cat)
# Out:
#                 Variable                                              Valor  \
# 9      antigüedad_empleo                                            9 years
# 8      antigüedad_empleo                                            8 years
# 7      antigüedad_empleo                                            7 years
# 6      antigüedad_empleo                                            6 years
# 4      antigüedad_empleo                                            4 years
# 5      antigüedad_empleo                                            5 years
# 11     antigüedad_empleo                                        desconocido
# 0      antigüedad_empleo                                             1 year
# 3      antigüedad_empleo                                            3 years
# 10     antigüedad_empleo                                           < 1 year
# 2      antigüedad_empleo                                            2 years
# 1      antigüedad_empleo                                          10+ years
# 46                estado                                            Default
# 47                estado  Does not meet the credit policy. Status:Charge...
# 48                estado  Does not meet the credit policy. Status:Fully ...
# 51                estado                                  Late (16-30 days)
# 50                estado                                    In Grace Period
# 52                estado                                 Late (31-120 days)
# 44                estado                                        Charged Off
# 45                estado                                            Current
# 49                estado                                         Fully Paid
# 31             finalidad                                        educational
# 38             finalidad                                   renewable_energy
# 41             finalidad                                            wedding
# 33             finalidad                                              house
# 36             finalidad                                             moving
# 40             finalidad                                           vacation
# 28             finalidad                                                car
# 39             finalidad                                     small_business
# 35             finalidad                                            medical
# 34             finalidad                                     major_purchase
# 37             finalidad                                              other
# 32             finalidad                                   home_improvement
# 29             finalidad                                        credit_card
# 30             finalidad                                 debt_consolidation
# 14  ingresos_verificados                                           Verified
# 12  ingresos_verificados                                       Not Verified
# 13  ingresos_verificados                                    Source Verified
# 43            num_cuotas                                          60 months
# 42            num_cuotas                                          36 months
# 21                rating                                                  G
# 20                rating                                                  F
# 19                rating                                                  E
# 18                rating                                                  D
# 15                rating                                                  A
# 17                rating                                                  C
# 16                rating                                                  B
# 24              vivienda                                               NONE
# 25              vivienda                                              OTHER
# 22              vivienda                                                ANY
# 26              vivienda                                                OWN
# 27              vivienda                                               RENT
# 23              vivienda                                           MORTGAGE
#
#     Frecuencia
# 9     0.035367
# 8     0.041012
# 7     0.041379
# 6     0.045521
# 4     0.060271
# 5     0.062176
# 11    0.064715
# 0     0.065506
# 3     0.081039
# 10    0.083405
# 2     0.090798
# 1     0.328810
# 46    0.000022
# 47    0.000431
# 48    0.000820
# 51    0.002006
# 50    0.003754
# 52    0.009759
# 44    0.118312
# 45    0.388268
# 49    0.476628
# 31    0.000187
# 38    0.000561
# 41    0.001093
# 33    0.006530
# 36    0.006925
# 40    0.007292
# 28    0.010363
# 39    0.011672
# 35    0.012419
# 34    0.022430
# 37    0.061464
# 32    0.065693
# 29    0.226434
# 30    0.566937
# 14    0.276989
# 12    0.331471
# 13    0.391540
# 43    0.286395
# 42    0.713605
# 21    0.005509
# 20    0.018554
# 19    0.060249
# 18    0.143590
# 15    0.191247
# 17    0.287942
# 16    0.292911
# 24    0.000022
# 25    0.000093
# 22    0.000381
# 26    0.111545
# 27    0.397653
# 23    0.490306

# %% [markdown]
# ### Análisis gráfico

# %%
def graficos_eda_categoricos(cat):
    
    #Calculamos el número de filas que necesitamos
    from math import ceil
    filas = ceil(cat.shape[1] / 2)

    #Definimos el gráfico
    f, ax = plt.subplots(nrows = filas, ncols = 2, figsize = (16, filas * 6))

    #Aplanamos para iterar por el gráfico como si fuera de 1 dimensión en lugar de 2
    ax = ax.flat 

    #Creamos el bucle que va añadiendo gráficos
    for cada, variable in enumerate(cat):
        cat[variable].value_counts().plot.barh(ax = ax[cada])
        ax[cada].set_title(variable, fontsize = 12, fontweight = "bold")
        ax[cada].tick_params(labelsize = 12)

# %%
graficos_eda_categoricos(cat[variables])

# %% [markdown]
# Conclusiones:
#
# En transformación:
#
# * En vivienda juntar ANY, NONE y OTHER a la categoria mayoritaria
# * En finalidad juntar renewable_energy, educational y wedding en 'otros'
# * Crear la target a partir de estado

# %% [markdown]
# ## EDA NUMÉRICAS

# %% [markdown]
# ### Análisis estadístico

# %%
def estadisticos_cont(num):
    #Calculamos describe
    estadisticos = num.describe().T
    #Añadimos la mediana
    estadisticos['median'] = num.median()
    #Reordenamos para que la mediana esté al lado de la media
    estadisticos = estadisticos.iloc[:,[0,1,8,2,3,4,5,6,7]]
    #Lo devolvemos
    return(estadisticos)

# %%
estadisticos_cont(num)
# Out:
#                                 count          mean    median           std  \
# ingresos                     139056.0  75129.466058  65000.00  42142.603041
# dti                          139056.0     18.891018     17.87     14.727938
# num_hipotecas                139056.0      1.504559      1.00      1.874163
# num_lineas_credito           139056.0     11.618111     11.00      5.632826
# porc_tarjetas_75p            139056.0     41.117677     33.30     36.442074
# porc_uso_revolving           139056.0     50.310299     50.30     24.673934
# num_cancelaciones_12meses    139056.0      0.008407      0.00      0.104935
# num_derogatorios             139056.0      0.198618      0.00      0.567233
# num_meses_desde_ult_retraso  139056.0     16.771905      0.00     23.027509
# principal                    139056.0  14989.077602  12800.00   9133.789795
# tipo_interes                 139056.0     13.096559     12.62      4.831379
# imp_cuota                    139056.0    444.539699    378.07    265.528115
# imp_amortizado               139056.0   9482.209706   7000.00   8270.031665
# imp_recuperado               139056.0    145.159032      0.00    768.094886
#
#                                 min         25%       50%       75%        max
# ingresos                       0.00  46000.0000  65000.00  92000.00  300000.00
# dti                           -1.00     12.0200     17.87     24.49     999.00
# num_hipotecas                  0.00      0.0000      1.00      2.00      32.00
# num_lineas_credito             0.00      8.0000     11.00     14.00      91.00
# porc_tarjetas_75p              0.00      0.0000     33.30     66.70     100.00
# porc_uso_revolving             0.00     31.7000     50.30     69.20     366.60
# num_cancelaciones_12meses      0.00      0.0000      0.00      0.00       7.00
# num_derogatorios               0.00      0.0000      0.00      0.00      46.00
# num_meses_desde_ult_retraso    0.00      0.0000      0.00     30.00     159.00
# principal                    500.00   8000.0000  12800.00  20000.00   40000.00
# tipo_interes                   5.31      9.4900     12.62     15.99      30.99
# imp_cuota                      7.61    251.4000    378.07    589.84    1714.54
# imp_amortizado                 0.00   3005.6475   7000.00  13800.00   40000.00
# imp_recuperado                 0.00      0.0000      0.00      0.00   33666.34

# %% [markdown]
# ### Análisis gráfico

# %%
def graficos_eda_continuas(num):
    
    #Calculamos el número de fila que necesitamos
    from math import ceil
    filas = ceil(num.shape[1] / 2)

    #Definimos el gráfico
    f, ax = plt.subplots(nrows = filas, ncols = 2, figsize = (16, filas * 6))

    #Aplanamos para iterar por el gráfico como si fuera de 1 dimensión en lugar de 2
    ax = ax.flat 

    #Creamos el bucle que va añadiendo gráficos
    for cada, variable in enumerate(num):
        num[variable].plot.density(ax = ax[cada])
        ax[cada].set_title(variable, fontsize = 12, fontweight = "bold")
        ax[cada].tick_params(labelsize = 12)

# %%
graficos_eda_continuas(num)

# %% [markdown]
# Vamos a analizar el detalle de imp_amortizado e imp_recuperado, ya que son relevantes para la target del modelo LGD.

# %%
ratios = num[['principal','imp_amortizado','imp_recuperado']].copy()

# %%
ratios['r_amortizado_principal'] = ratios.imp_amortizado / ratios.principal
ratios['r_recuperado_principal'] = ratios.imp_recuperado / ratios.principal

# %%
ratios.describe().T
# Out:
#                            count          mean          std    min  \
# principal               139056.0  14989.077602  9133.789795  500.0
# imp_amortizado          139056.0   9482.209706  8270.031665    0.0
# imp_recuperado          139056.0    145.159032   768.094886    0.0
# r_amortizado_principal  139056.0      0.662974     0.369116    0.0
# r_recuperado_principal  139056.0      0.009023     0.041634    0.0
#
#                                 25%           50%      75%           max
# principal               8000.000000  12800.000000  20000.0  40000.000000
# imp_amortizado          3005.647500   7000.000000  13800.0  40000.000000
# imp_recuperado             0.000000      0.000000      0.0  33666.340000
# r_amortizado_principal     0.274865      0.872009      1.0      1.000032
# r_recuperado_principal     0.000000      0.000000      0.0      1.207635

# %% [markdown]
# Conclusiones:
#
# * En transformación convertir num_derogatorios a binaria
# * Revisar en profundidad la relación entre estado e imp_recuperado

# %%
temp = cat[['estado']].merge(num[['imp_recuperado']], left_index=True, right_index=True)
temp.groupby('estado').imp_recuperado.mean()
# Out:
# estado
# Charged Off                                            1225.417872
# Current                                                   0.000000
# Default                                                   0.000000
# Does not meet the credit policy. Status:Charged Off     410.992833
# Does not meet the credit policy. Status:Fully Paid        0.000000
# Fully Paid                                                0.000000
# In Grace Period                                           0.000000
# Late (16-30 days)                                         0.000000
# Late (31-120 days)                                        0.000000
# Name: imp_recuperado, dtype: float64

# %% [markdown]
# Efectivamente sólo hay importe recuperado en el estado Charged Off.

# %% [markdown]
# ## GUARDAR DATASETS TRAS EDA

# %% [markdown]
# Guarda los avances en cat y num con un sufijo para poder guardar o recuperar avances del proyecto.
#
# En formato pickle para no perder las modificaciones de metadatos.
#
# *NOTA: En algunos casos no hay cambios en los ficheros en esta fase, así que este paso es opcional.Pero si no guardas estos ficheros acuérdate de modificar la importación en el siguiente notebook.*

# %%
#Definir los nombres de los archivos
ruta_cat = ruta_proyecto + '/02_Datos/03_Trabajo/' + 'cat_resultado_eda.pickle'
ruta_num = ruta_proyecto + '/02_Datos/03_Trabajo/' + 'num_resultado_eda.pickle'

# %%
#Guardar los archivos
cat.to_pickle(ruta_cat)
num.to_pickle(ruta_num)
